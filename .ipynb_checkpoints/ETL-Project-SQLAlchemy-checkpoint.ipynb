# %%
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func

# config.py in .gitignore
# you will have to apply own username/password
from config import username, password

# %%
rename_dict = {
    "Symbol": "symbol",
    "Name": "name",
    "LastSale": "last_sale",
    "Start of Year Sale": "start_year_sale",
    "YTD Change Percent": "ytd_per",
    "Sector": "sector"
}

# %%
nyse_csv = "NYSE_Sector_Performance.csv"
nyse_df = pd.read_csv(nyse_csv)
nyse_df = nyse_df.rename(columns=rename_dict)
nyse_df = nyse_df.set_index("symbol")
nyse_df = nyse_df.sort_index()
nyse_df
# Out:
#                                                      name  last_sale  \
# symbol
# A                              Agilent Technologies, Inc.     65.860
# AA                                      Alcoa Corporation     20.150
# AAC                                    AAC Holdings, Inc.      0.750
# AAN                                    Aaron&#39;s,  Inc.     61.560
# AAP                                Advance Auto Parts Inc    143.160
# AAT                           American Assets Trust, Inc.     45.580
# AB                         AllianceBernstein Holding L.P.     27.030
# ABB                                               ABB Ltd     18.050
# ABBV                                          AbbVie Inc.     65.230
# ABEV                                           Ambev S.A.      5.090
# ABM                           ABM Industries Incorporated     39.500
# ABT                                   Abbott Laboratories     83.160
# ACC                       American Campus Communities Inc     46.000
# ACCO                              Acco Brands Corporation      9.540
# ACH                 Aluminum Corporation of China Limited      7.310
# ACM                                                 AECOM     33.440
# ACN                                         Accenture plc    185.550
# ADC                              Agree Realty Corporation     67.290
# ADNT                                           Adient plc     19.300
# ADS                     Alliance Data Systems Corporation    152.130
# ADSW                     Advanced Disposal Services, Inc.     32.410
# ADT                                              ADT Inc.      5.610
# AEB                                              Aegon NV     23.750
# AEE                                    Ameren Corporation     75.050
# AEG                                              Aegon NV      4.370
# AEH                                              Aegon NV     26.120
# AEL       American Equity Investment Life Holding Company     22.300
# AEM                            Agnico Eagle Mines Limited     56.240
# AEO                       American Eagle Outfitters, Inc.     15.850
# AEP                 American Electric Power Company, Inc.     88.020
# ...                                                   ...        ...
# AOS                                 A.O Smith Corporation     43.650
# APD                      Air Products and Chemicals, Inc.    220.060
# AQN                     Algonquin Power & Utilities Corp.     12.610
# ARA               American Renal Associates Holdings, Inc      6.990
# ARE                 Alexandria Real Estate Equities, Inc.    142.670
# ARL                       American Realty Investors, Inc.     14.970
# ASIX                                        AdvanSix Inc.     23.230
# ATEN                                   A10 Networks, Inc.      7.090
# ATGE                        Adtalem Global Education Inc.     44.420
# ATI                   Allegheny Technologies Incorporated     19.580
# ATU                                   Actuant Corporation     20.890
# ATUS                                     Altice USA, Inc.     26.230
# ATV                             Acorn International, Inc.     17.838
# AXL          American Axle & Manufacturing Holdings, Inc.      8.550
# AXP                              American Express Company    120.720
# AYI                                  Acuity Brands, Inc.     127.560
# AYR                                     Aircastle Limited     19.500
# AYX                                         Alteryx, Inc.    125.650
# BABA                        Alibaba Group Holding Limited    153.670
# DDD                                3D Systems Corporation      8.240
# EGHT                                              8x8 Inc     23.320
# GOLF                              Acushnet Holdings Corp.     24.720
# HIVE                              Aerohive Networks, Inc.      4.450
# MMM                                            3M Company    164.710
# MO                                           Altria Group     46.650
# NFJ     AllianzGI NFJ Dividend, Interest & Premium Str...     12.050
# WBAI                                      500.com Limited      9.880
# WMS                       Advanced Drainage Systems, Inc.     33.310
# WUBA                                          58.com Inc.     51.330
# Y                                   Alleghany Corporation    675.020
#
#         start_year_sale    ytd_per                 sector
# symbol
# A               67.3224  -2.220468          Capital Goods
# AA              26.5800 -31.910670       Basic Industries
# AAC              1.4000 -86.666667            Health Care
# AAN             42.0215  31.738954             Technology
# AAP            157.4024  -9.948589      Consumer Services
# AAT             39.6779  12.948881      Consumer Services
# AB              26.3019   2.693674                Finance
# ABB             18.2678  -1.206648      Consumer Durables
# ABBV            89.8813 -37.791354            Health Care
# ABEV             3.9200  22.986248  Consumer Non-Durables
# ABM             31.7762  19.553924                Finance
# ABT             71.7027  13.777417            Health Care
# ACC             40.5584  11.829565      Consumer Services
# ACCO             6.6836  29.941300      Consumer Durables
# ACH              7.8200  -6.976744       Basic Industries
# ACM             26.5000  20.753589      Consumer Services
# ACN            139.8516  24.628618          Miscellaneous
# ADC             58.6511  12.838312      Consumer Services
# ADNT            15.0600  21.968912          Capital Goods
# ADS            148.9069   2.118649          Miscellaneous
# ADSW            23.9400  26.133909       Public Utilities
# ADT              5.9432  -5.939394      Consumer Services
# AEB             18.8400  20.673684                Finance
# AEE             64.3976  14.193738       Public Utilities
# AEG              4.4874  -2.686499                Finance
# AEH             25.1600   3.675345                Finance
# AEL             27.9400 -25.291480                Finance
# AEM             40.1592  28.593172       Basic Industries
# AEO             19.2095 -21.195584      Consumer Services
# AEP             73.5148  16.479436       Public Utilities
# ...                 ...        ...                    ...
# AOS             42.3365   3.009164      Consumer Durables
# APD            159.0737  27.713487       Basic Industries
# AQN              9.9368  21.199048       Public Utilities
# ARA             11.5200 -64.806867            Health Care
# ARE            114.4579  19.774374      Consumer Services
# ARL             12.0700  19.372077                Finance
# ASIX            24.3400  -4.778304       Basic Industries
# ATEN             6.2400  11.988717             Technology
# ATGE            47.3200  -6.528591      Consumer Services
# ATI             21.7700 -11.184883       Basic Industries
# ATU             20.9900  -0.478698             Technology
# ATUS            16.5200  37.018681      Consumer Services
# ATV             20.9310 -17.339388      Consumer Services
# AXL             11.1000 -29.824561          Capital Goods
# AXP             94.5967  21.639579                Finance
# AYI            114.7193  10.066400      Consumer Durables
# AYR             16.7400  14.153846             Technology
# AYX             59.4700  52.670115             Technology
# BABA           137.0700  10.802369          Miscellaneous
# DDD             10.1700 -23.422330             Technology
# EGHT            18.0400  22.641509             Technology
# GOLF            20.8282  15.743528  Consumer Non-Durables
# HIVE             3.2600  26.741573             Technology
# MMM            187.6263 -13.913120            Health Care
# MO              48.6960  -4.385852  Consumer Non-Durables
# NFJ             10.4806  13.024066                Finance
# WBAI             7.5800  23.279352      Consumer Services
# WMS             23.2791  30.113780          Capital Goods
# WUBA            54.2100  -5.610754             Technology
# Y              623.3200   7.659032                Finance
#
# [92 rows x 5 columns]

# %%
connect_string = f"postgresql://{username}:{password}@localhost:5432/ETL-Stocks"

engine = create_engine(connect_string)
connection = engine.connect()

# %%
table_name = "etl_stock_prices_2"
nyse_df.to_sql(name=table_name, con=connection, if_exists="append")
